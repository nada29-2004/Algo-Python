# %%
count = 0
while count <= 5:
    print(count)
    count = count + 1
else:
    print("en dohors de la boucle Fin : ",count)
#prints from 0 to 4
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# en dohors de la boucle Fin :  6

# %%
count = 0
while count < 5:
    print(count)
    count = count + 1
    if count == 3:
       break
else:
  print("valeur finale de cout:", count)



print(" Apres valeur finale de cout:", count)
# Out:
# 0
# 1
# 2
#  Apres valeur finale de cout: 3

# %%
numbers = [0, 1, 30,2, 3, 4, 5]
for number in numbers: # number is temporary name to refer to the list's items, valid only inside this loop
    if number %2==1: print(number)
# Out:
# 1
# 3
# 5

# %%
language = 'Test '
for letter in language:
    if letter=="P" :print(letter)

# %%
person1 = {
    'first_name':'Nome1',
    'last_name':'Yetayeh',
    'age':250,
    'country':'Finland',
    'is_marred':True,
    'skills':['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'grade':[20,20,20],
    'address':{
        'street':'Space street',
        'zipcode':'02210'
    }
}

person2 = {
    'first_name':'Name2',
    'last_name':'Yetayeh',
    'age':250,
    'country':'Finland',
    'is_marred':True,
    'skills':['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address':{
        'street':'Space street',
        'zipcode':'02210'
    }
}

# %%
d ={1:person1,2:person2, 3:person2}
for p in d:
  print(d[p])
# Out:
# {'first_name': 'Nome1', 'last_name': 'Yetayeh', 'age': 250, 'country': 'Finland', 'is_marred': True, 'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'], 'grade': [20, 20, 20], 'address': {'street': 'Space street', 'zipcode': '02210'}}
# {'first_name': 'Name2', 'last_name': 'Yetayeh', 'age': 250, 'country': 'Finland', 'is_marred': True, 'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'], 'address': {'street': 'Space street', 'zipcode': '02210'}}
# {'first_name': 'Name2', 'last_name': 'Yetayeh', 'age': 250, 'country': 'Finland', 'is_marred': True, 'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'], 'address': {'street': 'Space street', 'zipcode': '02210'}}

# %%
# on veut creer une classe de 30 etudiant
d={}
for i in range(30):
  d[i]= person1

# %%
for p in d:
  print(d[p]['first_name'],"---------->", d[p]['grade'])
# Out:
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]
# Nome1 ----------> [20, 20, 20]

# %%
person = {
    'first_name': 'Etudiant 1',
    'last_name': 'Yetayeh',
    'age': 25,
    'country': 'Finland',
    'is_marred': True,
    'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address': {
        'street': 'Space street',
        'zipcode': '02210'
    }
}
skill_x ="MongoDB"
for key in person:
    if key == 'skills':
        for skill in person['skills']:
            if skill ==skill_x and person['age'] >=20  and person['age'] <= 30: print(person['first_name'])
#afficher retenue si la personne possede cette competence el l'age entre 20 et 30
# Out:
# Etudiant 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)
